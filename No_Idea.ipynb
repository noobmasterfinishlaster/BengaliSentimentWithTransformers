# %% [markdown]
# <a href="https://colab.research.google.com/github/noobmasterfinishlaster/BengaliSentimentWithTransformers/blob/main/No_Idea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install emoji

# %%
pip install langdetect

# %%
pip install googletrans

# %%
# !pip install --upgrade googletrans==4.0.0-rc1
#restartRuntimeAFTERrUNNINGtHI

# %%
from google.colab import files
from googletrans import Translator
import pandas as pd

# Upload the Excel file
uploaded = files.upload()

# Assuming you uploaded a file named 'example.xlsx'
file_name = list(uploaded.keys())[0]

# Read the Excel file into a Pandas DataFrame
df = pd.read_excel(file_name)
# Out:
#      <input type="file" id="files-b5505439-f5e0-468d-83b1-7b5a555df4a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5505439-f5e0-468d-83b1-7b5a555df4a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import re

def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F700-\U0001F77F"  # alchemical symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                               u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                               u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                               u"\U00002702-\U000027B0"  # Dingbats
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
df['dtl'] = df['dtl'].apply(remove_emojis)

# %%
from langdetect import detect

def identify_language(text):
    try:
        lang = detect(text)
        return lang
    except:
        return 'unknown'

# Apply the language identification function to your DataFrame
df['language'] = df['dtl'].apply(identify_language)

# Display the DataFrame with the identified language column
df
# Out:
#      product_id                                                ttl  \
# 0        110649  Mohashankote Shhutki Tery ( Kishor Musa Robin ...
# 1         92278                                          Aparajito
# 2          8332                                    Pather Phachaly
# 3        133067                               Steal Like an Artist
# 4        238529                     The Almanack of Naval Ravikant
# ..          ...                                                ...
# 995      271408                             Biye O Patro Nirbachon
# 996      271413                             Biye O Patri Nirbachon
# 997      208199                              Bishasider Golpokotha
# 998      233204                                     Hizabi Konna 2
# 999      218011                                 The Caring Husband
#
#                                                    dtl language
# 0                    I think this book's story is fake       en
# ...

# %%
dfeng= df[df['language'].isin(['en'])]

# %%
dfben= df[df['language'].isin(['bn'])]

# %%
from googletrans import Translator
import pandas as pd

# Assuming dfben is your DataFrame
# dfben = pd.read_csv('your_dataframe.csv')  # You can read your DataFrame from a CSV file if not already loaded

# Create a Translator object
translator = Translator()

# Create an empty list to store the translated texts
translated_texts = []

# Iterate over each row in the DataFrame
for index, row in dfben.iterrows():
    # Assuming 'language' is the column containing Bengali text
    bengali_text = row['dtl']

    # Translate the Bengali text to English
    try:
        translated_text = translator.translate(bengali_text, dest='en').text
    except Exception as e:
        print(f"Translation error for index {index}: {e}")
        translated_text = None

    # Append the translated text to the list
    translated_texts.append(translated_text)

# Add a new column 'tl' to the DataFrame using .loc
dfben.loc[:, 'tl'] = translated_texts

# Print the updated DataFrame
dfben
# Out:
# Translation error for index 456: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 483: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 653: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 702: the JSON object must be str, bytes or bytearray, not NoneType
# <ipython-input-9-19773a9ad12f>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfben.loc[:, 'tl'] = translated_texts
#      product_id                                        ttl  \
# 1         92278                                  Aparajito
# 2          8332                            Pather Phachaly
# ...

# %%
from googletrans import Translator
import pandas as pd

# Assuming dfban is your DataFrame
# dfban = pd.read_csv('your_dataframe.csv')  # You can read your DataFrame from a CSV file if not already loaded

# Create a Translator object
translator = Translator()

# Create an empty list to store the translated texts
translated_texts = []

# Iterate over each row in the DataFrame
for index, row in dfben.iterrows():
    # Assuming 'language' is the column containing Bengali text
    bengali_text = row['dtl']

    # Translate the Bengali text to English
    try:
        translated_text = translator.translate(bengali_text, dest='en').text
    except Exception as e:
        print(f"Translation error for index {index}: {e}")
        translated_text = None

    # Append the translated text to the list
    translated_texts.append(translated_text)

# Add a new column 'translated_language' to the DataFrame
dfben['tttl'] = translated_texts

# Print the updated DataFrame
dfben
# Out:
# Translation error for index 456: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 483: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 653: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 702: the JSON object must be str, bytes or bytearray, not NoneType
# Translation error for index 992: 'Translator' object has no attribute 'raise_Exception'
# <ipython-input-10-86582e05dd70>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfben['tttl'] = translated_texts
#      product_id                                        ttl  \
# 1         92278                                  Aparajito
# ...

# %%
dfben1= dfben.rename(columns={'dtl': 'ban'})
dfben1
# Out:
#      product_id                                        ttl  \
# 1         92278                                  Aparajito
# 2          8332                            Pather Phachaly
# 5        167146  MATLAB: An Introduction with Applications
# 8         46919                         Tabijate Ruhullah
# 9        183616                 Physics 2nd Paper HSC 2023
# ..          ...                                        ...
# 995      271408                     Biye O Patro Nirbachon
# 996      271413                     Biye O Patri Nirbachon
# 997      208199                      Bishasider Golpokotha
# 998      233204                             Hizabi Konna 2
# 999      218011                         The Caring Husband
#
#                                                    ban language  \
# 1    আলহামদুলিল্লাহ অনেক ভালো ভাবে হাতে পেয়েছি। কোয়...       bn
# 2    আলহামদুলিল্লাহ অনেক ভালো ভাবে হাতে পেয়েছি। কোয়...       bn
# ...

# %%
dfben1= dfben1.rename(columns={'tl': 'dtl'})
dfben1
# Out:
#      product_id                                        ttl  \
# 1         92278                                  Aparajito
# 2          8332                            Pather Phachaly
# 5        167146  MATLAB: An Introduction with Applications
# 8         46919                         Tabijate Ruhullah
# 9        183616                 Physics 2nd Paper HSC 2023
# ..          ...                                        ...
# 995      271408                     Biye O Patro Nirbachon
# 996      271413                     Biye O Patri Nirbachon
# 997      208199                      Bishasider Golpokotha
# 998      233204                             Hizabi Konna 2
# 999      218011                         The Caring Husband
#
#                                                    ban language  \
# 1    আলহামদুলিল্লাহ অনেক ভালো ভাবে হাতে পেয়েছি। কোয়...       bn
# 2    আলহামদুলিল্লাহ অনেক ভালো ভাবে হাতে পেয়েছি। কোয়...       bn
# ...

# %%
baneng = pd.concat([dfben1,dfeng])
baneng
# Out:
#      product_id                                                ttl  \
# 1         92278                                          Aparajito
# 2          8332                                    Pather Phachaly
# 5        167146          MATLAB: An Introduction with Applications
# 8         46919                                 Tabijate Ruhullah
# 9        183616                         Physics 2nd Paper HSC 2023
# ..          ...                                                ...
# 942      157682                                   Nijhum Nishirate
# 943      204806                                             Remedy
# 961      186614  The Royal Guide for Engineering and Varsity Ad...
# 975      203637  Consummate English Text Book For HSC and Alim ...
# 976      261302              ঢেঁকিছাঁটা Ganjia Rice (গাঞ্জিয়া চাল)
#
#                                                    ban language  \
# 1    আলহামদুলিল্লাহ অনেক ভালো ভাবে হাতে পেয়েছি। কোয়...       bn
# ...

# %%
example = baneng['dtl'][40]
print(example)
# Out:
# If you read it for undergraduate no longer seeing YouTube it doesn't have to be nasty to the head

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
print(nltk.data.path)
# Out:
# ['/root/nltk_data', '/usr/nltk_data', '/usr/share/nltk_data', '/usr/lib/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import nltk
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.7003}

# %%
res = {}

for i, row in tqdm(baneng.iterrows(), total=len(baneng)):
    text = row['dtl']
    myid = row['product_id']

    # Check if text is not None before performing sentiment analysis
    if text is not None:
        res[myid] = sia.polarity_scores(text)
    else:
        # Handle the case where text is None (e.g., print a message or assign a default sentiment)
        print(f"Skipping sentiment analysis for product_id {myid} because text is None")

# Continue with the rest of your code
# Out:
#   0%|          | 0/850 [00:00<?, ?it/s]
# Skipping sentiment analysis for product_id 271616 because text is None
# Skipping sentiment analysis for product_id 271616 because text is None
# Skipping sentiment analysis for product_id 227535 because text is None
# Skipping sentiment analysis for product_id 262711 because text is None

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'product_id'})
vaders = vaders.merge(baneng, how='left')

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
def polirty_scores_roberta (example):
  encoded_text = tokenizer(example, return_tensors='pt')
  output=model(**encoded_text)
  scores = output[0][0].detach().numpy()
  scores = softmax(scores)
  scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
  }

  return scores_dict

# %%
pip install tqdm

# %%
res = {}
for i, row in tqdm(baneng.iterrows(), total=len(baneng)):
    try:
        text = row['dtl']
        myid = row['product_id']

        # Check if 'dtl' is not None or NaN
        if text is not None and pd.notna(text):
            vader_result = sia.polarity_scores(text)
            vader_result_rename = {}
            for key, value in vader_result.items():
                vader_result_rename[f"vader_{key}"] = value

            roberta_result = polirty_scores_roberta(text)
            both = {**vader_result_rename, **roberta_result}
            res[myid] = both
        else:
            print(f'Skipping row with product_id {myid} due to missing or None value in "dtl" column')
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/850 [00:00<?, ?it/s]
# Broke for id 221112
# Broke for id 203134
# Broke for id 21151
# Broke for id 230843
# Broke for id 224838
# Broke for id 228859
# Skipping row with product_id 271616 due to missing or None value in "dtl" column
# Skipping row with product_id 271616 due to missing or None value in "dtl" column
# Skipping row with product_id 227535 due to missing or None value in "dtl" column
# Broke for id 224872
# Skipping row with product_id 262711 due to missing or None value in "dtl" column
# Broke for id 268966
# Broke for id 268968
# Broke for id 268971
# Broke for id 268966
# Broke for id 268971
# Broke for id 220115
# Broke for id 222189

# %%
roberta = pd.DataFrame(res).T
roberta = roberta.reset_index().rename(columns={'index': 'product_id'})
roberta = roberta.merge(baneng, how='left')
ratul = roberta

# %%
ratul['roberta_compound'] = ratul['roberta_pos'] - ratul['roberta_neg'] + ratul['roberta_neu']

# %%
ratul['scaled_roberta_compound'] = ratul['roberta_compound'].apply(lambda x: min(10, max(1, x * 10)) if x >= 0 else 1)

# %%
ratul.columns
# Out:
# Index(['product_id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ttl', 'ban', 'language',
#        'dtl', 'tttl', 'roberta_compound', 'scaled_roberta_compound'],
#       dtype='object')

# %%
ratul = ratul.drop(['vader_neg','vader_neu','vader_pos','vader_compound',	'roberta_neg',	'roberta_neu','roberta_pos','roberta_compound','tttl',], axis=1)

# %%
Table2=ratul
Table2.to_excel('T-2.xlsx', index=False)

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import pandas as pd

# Assuming 'scaled_roberta_compound' and 'ttl' are columns in your dataframe
# Change 'ratul' to the actual name of your dataframe
result_df = ratul.groupby(['product_id', 'ttl'])['scaled_roberta_compound'].agg(['mean', 'count']).reset_index()

# Rename the columns for clarity
result_df.columns = ['product_id', 'ttl', 'average_scaled_roberta_compound', 'count']

# Display the resulting dataframe
ratul2 = result_df

# %%
ratul2.to_excel('T-1.xlsx', index=False)

# %%
# !pip install xlsxwriter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
with pd.ExcelWriter('output_file.xlsx', engine='xlsxwriter') as writer:
    ratul.to_excel(writer, sheet_name='Sheet1', index=False)
    ratul2.to_excel(writer, sheet_name='Sheet2', index=False)
